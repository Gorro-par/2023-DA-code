# %% [markdown]
# ## matplotlib 중급
#
# ## 설치 점검 및 모듈 확인

# %%
import sys
print(sys.version)
sys.path
# Out:
# 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]
# ['C:\\Users\\102',
#  'C:\\Users\\102\\anaconda3\\python39.zip',
#  'C:\\Users\\102\\anaconda3\\DLLs',
#  'C:\\Users\\102\\anaconda3\\lib',
#  'C:\\Users\\102\\anaconda3',
#  '',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\102\\.ipython']

# %%
import site
site.getsitepackages()
# Out:
# ['C:\\Users\\102\\anaconda3', 'C:\\Users\\102\\anaconda3\\lib\\site-packages']

# %%
import matplotlib as mpl
mpl.__version__
# Out:
# '3.5.2'

# %%
import numpy as np
np.__version__
# Out:
# '1.21.5'

# %%
# 1. 모듈 설치 koreanize-matplotlib
# 참조 사이트 https://github.com/ychoi-kr/koreanize-matplotlib
# !pip install koreanize-matplotlib
# 2. 한글을 선명하게
# %config InlineBackend.figure_format = 'retina'

# %%
# 3. 바로 실행 테스트
import koreanize_matplotlib
import matplotlib.pyplot as plt
plt.plot([-1, 0, 1, 2])
plt.title('그래프 제목',
fontweight="bold")
plt.xlabel('간단한 그래프')
plt.show()

# %%
import matplotlib.pyplot as pit 
import numpy as np

x= np.linspace(-2 * np.pi, 2 *np.pi, 200) # 0에서 2*01까지 경계선을 포함해 199등분
pit. plot(x, np.sin(x) *10)
pit. plot (x, x**2)
pit. plot (x, 2 * x**2 - 3*x)
pit.grid(True)
pit.title('다양한 그래프')
pit. show()

# %%
import matplotlib.pyplot as plt

arrays, bins, patches = plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %%
import random
import matplotlib.pyplot as plt

dice = []

for i in range(5) :
    dice.append(random.randint(1,6))
    
plt.hist(dice,  bins=6)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ax1 = plt.subplot(2,1,1)
plt.plot(np.random.randint(1, 10, 10), 'yo-')
plt.title('a tale of 2 subplots')
plt.ylabel('damped osciliation')
print(ax1)

ax2 = plt.subplot(2,1,2)
plt.plot(np.arange(10), np.arange(10) * 2, 'r.-')
plt.title('a tale of 2 subplots')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# AxesSubplot(0.125,0.53;0.775x0.35)
# AxesSubplot(0.125,0.11;0.775x0.35)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(range(-20, 80), np.random.randn(100).cumsum(), 'r--')
plt.title('한글 점검');

# %%
fig = plt.figure(figsize=(15, 12))
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'),
figsize=(15, 12))
graph_title = '테스트'
ax.set_title(f'{graph_title}')
ax.set_xlabel('주파수 (Hz)', labelpad=20)
ax.set_ylabel('초 (s)', labelpad=20)
ax.set_zlabel('강도/주파수 (dB/Hz)', labelpad=20)
ax.view_init(20, 20)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 8))
ax1 = fig.add_subplot(2,2,1)
plt.plot(np.random.randn(50).cumsum(), "g--")

ax2 = fig.add_subplot(2,2,2)
plt.plot(np.random.randn(50).cumsum(), "r--")

ax3 = fig.add_subplot(2,2,3)
plt.plot(np.random.randn(50).cumsum(), "m--")

ax4 = fig.add_subplot(2,2,3)
plt.plot(np.random.randn(50).cumsum(), "c--")
